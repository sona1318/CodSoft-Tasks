# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
<style>
    :root {
        --bg-color: #e0f2f1;
        --card-bg: #ffffff;
        --primary-green: #00695c;
        --text-dark: #333;
        --text-light: #777;
        --price-orange: #ff8f00;
    }

    .mobile-container {
        width: 360px;
        height: 640px;
        background-color: var(--bg-color);
        border: 12px solid #333;
        border-radius: 30px;
        margin: 20px auto;
        overflow-y: scroll;
        font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
        position: relative;
        box-shadow: 0 10px 20px rgba(0,0,0,0.2);
    }

    /* Hide scrollbar for Chrome, Safari and Opera */
    .mobile-container::-webkit-scrollbar { display: none; }

    header {
        padding: 20px;
        display: flex;
        justify-content: space-between;
        align-items: center;
    }

    .search-bar {
        background: white;
        padding: 10px;
        margin: 0 20px;
        border-radius: 10px;
        color: #ccc;
        font-size: 0.9em;
    }

    .categories {
        display: flex;
        padding: 15px 20px;
        gap: 15px;
        overflow-x: auto;
        white-space: nowrap;
    }

    .category { font-weight: bold; color: var(--text-light); }
    .category.active { color: var(--text-dark); border-bottom: 2px solid var(--text-dark); }

    .menu-grid {
        display: grid;
        grid-template-columns: 1fr 1fr;
        gap: 15px;
        padding: 20px;
    }

    .food-card {
        background: var(--card-bg);
        border-radius: 15px;
        padding: 10px;
        text-align: center;
        box-shadow: 0 4px 6px rgba(0,0,0,0.05);
    }

    .food-img {
        width: 100%;
        height: 100px;
        background-color: #f0f0f0;
        border-radius: 10px;
        object-fit: cover;
    }

    .food-info { text-align: left; margin-top: 8px; }
    .food-name { font-size: 0.85em; font-weight: bold; margin-bottom: 4px; }
    .food-meta { font-size: 0.7em; color: var(--text-light); display: flex; justify-content: space-between; }
    .food-price { color: var(--price-orange); font-weight: bold; margin-top: 5px; }

    .nav-bar {
        position: sticky;
        bottom: 0;
        background: white;
        display: flex;
        justify-content: space-around;
        padding: 15px;
        border-top: 1px solid #eee;
    }
</style>
</head>
<body>

<div class="mobile-container">
    <header>
        <h2 style="margin:0">Menu</h2>
        <div style="background: var(--primary-green); color:white; padding:5px; border-radius:5px;">🛒</div>
    </header>

    <div class="search-bar">🔍 Search</div>

    <div class="categories">
        <span class="category active">All</span>
        <span class="category">Breakfast</span>
        <span class="category">Lunch</span>
        <span class="category">Treats</span>
        <span class="category">Dessert</span>
    </div>

    <div class="menu-grid">
        <div class="food-card">
            <img class="food-img" src="https://images.unsplash.com/photo-1506084868730-342b1f452577?auto=format&fit=crop&w=200&q=80" alt="pancakes">
            <div class="food-info">
                <div class="food-name">Pear & Orange</div>
                <div class="food-meta"><span>⏱ 20 min</span> <span>⭐ 4.8</span></div>
                <div class="food-price">25.00$</div>
            </div>
        </div>
        <div class="food-card">
            <img class="food-img" src="https://images.unsplash.com/photo-1497034825429-c343d7c6a68f?auto=format&fit=crop&w=200&q=80" alt="meat">
            <div class="food-info">
                <div class="food-name">Meat & Mushroom</div>
                <div class="food-meta"><span>⏱ 30 min</span> <span>⭐ 5.0</span></div>
                <div class="food-price">37.00$</div>
            </div>
        </div>
        <div class="food-card">
            <img class="food-img" src="https://images.unsplash.com/photo-1525351484163-7529414344d8?auto=format&fit=crop&w=200&q=80" alt="egg">
            <div class="food-info">
                <div class="food-name">Egg & Bread</div>
                <div class="food-meta"><span>⏱ 10 min</span> <span>⭐ 4.7</span></div>
                <div class="food-price">25.00$</div>
            </div>
        </div>
        <div class="food-card">
            <img class="food-img" src="https://images.unsplash.com/photo-1571091718767-18b5b1457add?auto=format&fit=crop&w=200&q=80" alt="pancake2">
            <div class="food-info">
                <div class="food-name">Sweet Pancake</div>
                <div class="food-meta"><span>⏱ 12 min</span> <span>⭐ 4.9</span></div>
                <div class="food-price">13.00$</div>
            </div>
        </div>
    </div>

    <div class="nav-bar">
        <span>🏠</span>
        <span>🤍</span>
        <span>📋</span>
        <span>👤</span>
    </div>
</div>

</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#     :root {
#         --bg-color: #e0f2f1;
#         --card-bg: #ffffff;
#         --primary-green: #00695c;
#         --text-dark: #333;
#         --text-light: #777;
#         --price-orange: #ff8f00;
#     }
#
#     .mobile-container {
#         width: 360px;
#         height: 640px;
#         background-color: var(--bg-color);
#         border: 12px solid #333;
#         border-radius: 30px;
#         margin: 20px auto;
#         overflow-y: scroll;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         position: relative;
#         box-shadow: 0 10px 20px rgba(0,0,0,0.2);
#     }
#
#     /* Hide scrollbar for Chrome, Safari and Opera */
#     .mobile-container::-webkit-scrollbar { display: none; }
#
#     header {
#         padding: 20px;
#         display: flex;
#         justify-content: space-between;
#         align-items: center;
#     }
#
#     .search-bar {
#         background: white;
# ...
