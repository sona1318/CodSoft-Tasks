# %%
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
<style>
body {
    font-family: Arial, sans-serif;
    background: linear-gradient(to right, #cfd9df, #e2ebf0);
    display: flex;
    justify-content: center;
    padding: 30px;
}

.container {
    display: flex;
    gap: 30px;
}

.card {
    background: white;
    width: 250px;
    padding: 20px;
    border-radius: 25px;
    box-shadow: 0px 5px 15px rgba(0,0,0,0.2);
    text-align: center;
}

h2 {
    color: #5a67d8;
}

input {
    width: 90%;
    padding: 10px;
    margin: 8px 0;
    border-radius: 10px;
    border: 1px solid #ccc;
}

button {
    width: 100%;
    padding: 10px;
    border-radius: 20px;
    border: none;
    background: linear-gradient(to right, #667eea, #764ba2);
    color: white;
    font-size: 16px;
    cursor: pointer;
}

.social {
    margin: 10px;
}

.footer {
    font-size: 12px;
    margin-top: 10px;
}

</style>
</head>

<body>

<div class="container">

<!-- Welcome -->
<div class="card">
    <h2>Welcome</h2>
    <p>Please login or sign up to continue</p>
    
    <div class="social">
        <button>Facebook</button>
        <button>Twitter</button>
    </div>
    
    <p>or login with email</p>
    
    <button>Sign Up</button>
    <div class="footer">Already have account? Login</div>
</div>

<!-- Sign Up -->
<div class="card">
    <h2>Sign Up</h2>
    
    <input type="text" placeholder="Email">
    <input type="password" placeholder="Password">
    
    <p><input type="checkbox"> I agree with privacy policy</p>
    
    <button>Sign Up</button>
    
    <div class="footer">Already have account? Login</div>
</div>

<!-- Login -->
<div class="card">
    <h2>Login</h2>
    
    <input type="text" placeholder="Email">
    <input type="password" placeholder="Password">
    
    <p>Forgot Password?</p>
    
    <button>Login</button>
    
    <div class="footer">Don't have account? Sign Up</div>
</div>

</div>

</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# body {
#     font-family: Arial, sans-serif;
#     background: linear-gradient(to right, #cfd9df, #e2ebf0);
#     display: flex;
#     justify-content: center;
#     padding: 30px;
# }
#
# .container {
#     display: flex;
#     gap: 30px;
# }
#
# .card {
#     background: white;
#     width: 250px;
#     padding: 20px;
#     border-radius: 25px;
#     box-shadow: 0px 5px 15px rgba(0,0,0,0.2);
#     text-align: center;
# }
#
# h2 {
#     color: #5a67d8;
# }
#
# input {
#     width: 90%;
#     padding: 10px;
#     margin: 8px 0;
#     border-radius: 10px;
#     border: 1px solid #ccc;
# }
#
# button {
#     width: 100%;
#     padding: 10px;
#     border-radius: 20px;
#     border: none;
#     background: linear-gradient(to right, #667eea, #764ba2);
#     color: white;
#     font-size: 16px;
#     cursor: pointer;
# }
#
# .social {
#     margin: 10px;
# }
#
# .footer {
#     font-size: 12px;
#     margin-top: 10px;
# }
#
# </style>
# </head>
#
# <body>
#
# <div class="container">
#
# <!-- Welcome -->
# <div class="card">
#     <h2>Welcome</h2>
#     <p>Please login or sign up to continue</p>
#
#     <div class="social">
#         <button>Facebook</button>
#         <button>Twitter</button>
#     </div>
#
#     <p>or login with email</p>
#
#     <button>Sign Up</button>
#     <div class="footer">Already have account? Login</div>
# </div>
#
# <!-- Sign Up -->
# <div class="card">
#     <h2>Sign Up</h2>
#
#     <input type="text" placeholder="Email">
#     <input type="password" placeholder="Password">
#
#     <p><input type="checkbox"> I agree with privacy policy</p>
#
#     <button>Sign Up</button>
#
#     <div class="footer">Already have account? Login</div>
# </div>
#
# <!-- Login -->
# <div class="card">
#     <h2>Login</h2>
#
#     <input type="text" placeholder="Email">
#     <input type="password" placeholder="Password">
#
#     <p>Forgot Password?</p>
#
#     <button>Login</button>
#
#     <div class="footer">Don't have account? Sign Up</div>
# </div>
#
# </div>
#
# </body>
# </html>
